# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated, List
import operator
from langgraph.checkpoint.sqlite import SqliteSaver
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage, ChatMessage
import sqlite3 
from langgraph.checkpoint.sqlite import SqliteSaver 
conn = sqlite3.connect("checkpoints.db", check_same_thread=False) 
memory = SqliteSaver(conn)

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()

os.environ['GOOGLE_API_KEY'] = os.getenv('GEMINI_API_KEY') 
os.environ['TAVILY_API_KEY'] = os.getenv('TAVILY_API_KEY')

# %%
from typing import TypedDict, List


class AgentState(TypedDict):
    task: str
    plan: str
    draft: str
    critique: str
    content: List[str]
    revision_number: int
    max_revisions: int

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model='gpt-5-nano',
    temperature=0,
    api_key=os.getenv('OPENAI_API_KEY')
)

# %%
PLAN_PROMPT = """Você é um escritor especialista com a tarefa de criar um esboço de alto nível para uma redação. \
Escreva esse esboço para o tópico fornecido pelo usuário. Apresente um plano da redação junto com quaisquer notas \
ou instruções relevantes para as seções."""

# %%
WRITER_PROMPT = """Você é um assistente de redação com a tarefa de escrever excelentes redações de 5 parágrafos. \
Gere a melhor redação possível para a solicitação do usuário e o esboço inicial. \
Se o usuário fornecer críticas, responda com uma versão revisada das suas tentativas anteriores. \
Utilize todas as informações abaixo conforme necessário:

------

{content}"""

# %%
REFLECTION_PROMPT = """Você é um professor corrigindo uma redação submetida. \
Gere uma crítica e recomendações para a submissão do usuário. \
Forneça recomendações detalhadas, incluindo pedidos sobre extensão, profundidade, estilo, etc."""

# %%
RESEARCH_PLAN_PROMPT = """Você é um pesquisador encarregado de fornecer informações que podem \
ser usadas ao escrever a seguinte redação. Gere uma lista de consultas de pesquisa que \
recolham quaisquer informações relevantes. Gere no máximo 3 consultas."""

# %%
RESEARCH_CRITIQUE_PROMPT = """Você é um pesquisador encarregado de fornecer informações que podem \
ser usadas ao fazer quaisquer revisões solicitadas (conforme descrito abaixo). \
Gere uma lista de consultas de pesquisa que recolham quaisquer informações relevantes. Gere no máximo 3 consultas."""

# %%
from pydantic import BaseModel

class Queries(BaseModel):
    queries: List[str]

# %%
from tavily import TavilyClient
import os
tavily = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

# %%
def plan_node(state: AgentState):
    messages = [
        SystemMessage(content=PLAN_PROMPT), 
        HumanMessage(content=state['task'])
    ]
    response = model.invoke(messages)
    return {"plan": response.content}

# %%
def research_plan_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_PLAN_PROMPT),
        HumanMessage(content=state['task'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def generation_node(state: AgentState):
    content = "\n\n".join(state['content'] or [])
    user_message = HumanMessage(
        content=f"{state['task']}\n\nHere is my plan:\n\n{state['plan']}")
    messages = [
        SystemMessage(
            content=WRITER_PROMPT.format(content=content)
        ),
        user_message
        ]
    response = model.invoke(messages)
    return {
        "draft": response.content, 
        "revision_number": state.get("revision_number", 1) + 1
    }

# %%
def reflection_node(state: AgentState):
    messages = [
        SystemMessage(content=REFLECTION_PROMPT), 
        HumanMessage(content=state['draft'])
    ]
    response = model.invoke(messages)
    return {"critique": response.content}

# %%
def research_critique_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_CRITIQUE_PROMPT),
        HumanMessage(content=state['critique'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def should_continue(state):
    if state["revision_number"] > state["max_revisions"]:
        return END
    return "reflect"

# %%
builder = StateGraph(AgentState)

# %%
builder.add_node("planner", plan_node)
builder.add_node("generate", generation_node)
builder.add_node("reflect", reflection_node)
builder.add_node("research_plan", research_plan_node)
builder.add_node("research_critique", research_critique_node)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 builder.add_node("generate", generation_node)
#       2 builder.add_node("reflect", reflection_node)
#       3 builder.add_node("research_plan", research_plan_node)
#       4 builder.add_node("research_critique", research_critique_node)
#
# File ~/Study/Alura/LangGraph_Orquestrando_agentes/.venv/lib/python3.12/site-packages/langgraph/graph/state.py:793, in StateGraph.add_node(self, node, action, defer, metadata, input_schema, retry_policy, cache_policy, error_handler, destinations, timeout, **kwargs)
#     791     raise RuntimeError
#     792 if node in self.nodes:
# --> 793     raise ValueError(f"Node `{node}` already present.")
#     794 if node == END or node == START:
#     795     raise ValueError(f"Node `{node}` is reserved.")
#
# ValueError: Node `generate` already present.

# %%
builder.set_entry_point("planner")

# %%
builder.add_conditional_edges("generate", should_continue, {END: END, "reflect": "reflect"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 builder.add_conditional_edges("generate", should_continue, {END: END, "reflect": "reflect"})
#
# File ~/Study/Alura/LangGraph_Orquestrando_agentes/.venv/lib/python3.12/site-packages/langgraph/graph/state.py:1010, in StateGraph.add_conditional_edges(self, source, path, path_map)
#    1008 # validate the condition
#    1009 if name in self.branches[source]:
# -> 1010     raise ValueError(
#    1011         f"Branch with name `{path.name}` already exists for node `{source}`"
#    1012     )
#    1013 # save it
#    1014 self.branches[source][name] = BranchSpec.from_path(path, path_map, True)
#
# ValueError: Branch with name `should_continue` already exists for node `generate`

# %%
builder.add_edge("planner", "research_plan")
builder.add_edge("research_plan", "generate")

builder.add_edge("reflect", "research_critique")
builder.add_edge("research_critique", "generate")

# %%
builder.set_entry_point("plan")
builder.add_edge("plan", "research_plan")

# %%
graph = builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display, Markdown
import os

print("\n--- Tentando Gerar PNG do Grafo via Mermaid (Requer Playwright!) ---")
try:

    image_data = graph.get_graph().draw_mermaid_png()
    display(Image(data=image_data))
    print("Grafo PNG gerado e exibido com sucesso!")

except Exception as e:

    print(f"\nErro ao tentar gerar o PNG do grafo: {e}")
    print("Isso pode ocorrer por:")
    print("1. O método `.draw_mermaid_png()` não existe na sua versão do LangGraph.")
    print("2. Faltam dependências como 'playwright' ou seus drivers não foram instalados.")
    print("   Tente: pip install playwright && playwright install")
    print("3. Outro erro inesperado ao acessar o grafo ou renderizar.")

    print("\n--- Tentando gerar apenas o código Mermaid (Fallback) ---")
    try:

        mermaid_code = graph.get_graph().draw_mermaid()
        print("\n--- Código Mermaid Gerado (Cole em https://mermaid.live/ ou use Markdown no notebook) ---")
        print(mermaid_code)

    except Exception as e_mermaid:
        print(f"Erro ao gerar código Mermaid: {e_mermaid}")
        print("Verifique se 'graph.get_graph()' está correto e acessível.")
# Out:
# --- Tentando Gerar PNG do Grafo via Mermaid (Requer Playwright!) ---
# Grafo PNG gerado e exibido com sucesso!

# %%
thread = {"configurable": {"thread_id": "1"}}
for s in graph.stream({
    'task': "Qual é a diferença entre o langchain e langsmith",
    "max_revisions": 2,
    "revision_number": 1,
    "content": [], 
}, thread):
    print(s)
# Out:
# {'plan': {'plan': 'Resumo rápido\n- LangChain é um framework de código aberto para construir aplicações que utilizam modelos de linguagem (LLMs). Oferece módulos para prompts, cadeias de processamento (chains), agentes, memória, integrações com provedores de LLMs e ferramentas de orquestração.\n- LangSmith é uma plataforma/serviço complementar da família LangChain voltada à observabilidade, teste e depuração de aplicações que usam LangChain. Ela coleta logs de execuções, métricas, permite replays de runs e facilita a avaliação de desempenho e qualidade de prompts.\n\nPlano de redação: Diferença entre LangChain e LangSmith\n\n1) Introdução\n- Objetivo: situar as duas ferramentas no ecossistema de IA/LLMs.\n- Tese: LangChain é o framework de construção de aplicações com LLMs; LangSmith é a plataforma de observabilidade e avaliação que complementa o desenvolvimento com LangChain.\n- Nota para o escritor: apresente a ideia de que as ferramentas atendem a fases diferentes do ciclo de vida de um app de LLM (construção vs observação/depuração).\n\n2) Definições claras de cada ferramenta\n- LangChain: descreva como framework open-source que facilita a criação de pipelines de LLMs, com componentes como prompts templates, wrappers de LLM, memory, vector stores, chains, e agents.\n- LangSmith: descreva como plataforma de observabilidade/monitoramento para LangChain, com coleta de dados de execuções (runs), prompts, respostas, métricas, replays e ferramentas de análise.\n\n3) Propósito e foco\n- LangChain: foco no desenvolvimento rápido de aplicações com LLMs, abstrações para prompts, encadeamento de etapas (chains), tomada de decisões por agentes, integração com ferramentas externas.\n- LangSmith: foco no monitoramento, diagnóstico, avaliação de desempenho, qualidade de prompts, reprodutibilidade de execuções, auditoria.\n\n4) Principais componentes e funcionalidades (diferenças técnicas)\n- LangChain (principais componentes a mencionar): prompt templates, LLM wrappers, chains, agents, memory, vector stores, tools, callbacks.\n- LangSmith (principais recursos a mencionar): registro de runs, logs de prompts e respostas, métricas de desempenho, dashboards, replays de execuções, comparação de versões de prompts, auditoria.\n- Nota para o escritor: utilize exemplos simples para ilustrar cada componente (ex.: “um chain que recolhe dados de usuário, consulta um LLM e retorna resposta” vs “replay de uma execução para ver como mudou a resposta entre versões de prompt”).\n\n5) Casos de uso típicos\n- LangChain: construção de chatbots, assistentes, pipelines de PNL, sistemas de perguntas e respostas, automação de tarefas com LLMs.\n- LangSmith: monitoramento de performance de prompts, depuração de falhas, comparação entre versões de prompts, avaliação de qualidade, conformidade/auditoria.\n- Nota: enfatize como um pode funcionar sem o outro (ex.: é possível usar LangChain sem LangSmith, mas a observabilidade de LangSmith facilita iterações mais rápidas).\n\n6) Como eles se complementam\n- Descreva um fluxo típico de projeto: usar LangChain para desenvolver a solução, definir prompts e cadeias; usar LangSmith para monitorar runs, coletar métricas, testar alterações de prompts e identificar gargalos.\n- Dicas de integração prática: como mapear componentes de LangChain para métricas relevantes em LangSmith.\n\n7) Limitações e considerações\n- LangChain: depende do ecossistema de código/ambiente do desenvolvedor; curva de aprendizado para entender módulos (chains, agents, memory).\n- LangSmith: é uma ferramenta de observabilidade que pode ter custos e exige configuração para capturar dados relevantes; considerar privacidade/segurança de logs.\n- Observação sobre versões: alinhar versões do LangChain com o suporte da LangSmith; manter-se atento a atualizações.\n\n8) Conclusão\n- Reforce a diferença essencial: LangChain constrói; LangSmith observa e valida.\n- Enfatize a vantagem de usar os dois juntos para acelerar desenvolvimento, melhoria contínua e  ...
# {'planner': {'plan': 'Aqui está um esboço de alto nível para uma redação sobre a diferença entre LangChain e LangSmith, com notas/instruções para cada seção.\n\nTítulo sugerido\n- Diferenças entre LangChain e LangSmith: framework de construção vs plataforma de observabilidade\n\nPropósito e público\n- Propósito: explicar claramente o que cada ferramenta faz, como se complementam e em que situações cada uma é apropriada.\n- Público-alvo: desenvolvedores de aplicações com LLM, engenheiros de IA/QA, gestores de projetos de IA que precisam entender o ecossistema LangChain.\n\nPlano da redação (seções) com notas para o autor\n\n1) Introdução\n- O que apresentar:\n  - Contexto da popularidade de aplicações baseadas em LLM.\n  - A existência de várias ferramentas no ecossistema LangChain.\n  - A tese: LangChain é o framework para construir aplicações; LangSmith é a plataforma de observabilidade/QA para essas aplicações.\n- Notas para o autor:\n  - Defina termos logo de início: o que é uma “aplicação LangChain” (encadeamento de chamadas a LLMs, agentes, memória, etc.) e o que é observabilidade/QA em LLMs.\n  - Indique que as duas ferramentas são complementares, não concorrentes.\n\n2) Definições rápidas: o que é LangChain e o que é LangSmith\n- LangChain:\n  - Descrição: biblioteca/framework de código para construir aplicações com LLMs (chains, agents, memory, prompts, integrações com modelos, utilitários de dados).\n  - Público principal: desenvolvedores que querem orquestrar fluxos de prompts e interações com LLMs.\n- LangSmith:\n  - Descrição: plataforma (observabilidade, teste, depuração e análise de execuções de aplicações LangChain) que registra runs, prompts, entradas/saídas, métricas e facilita a reprodução e o diagnóstico.\n  - Público principal: engenheiros de QA/ops, cientistas de dados de produção, equipes que precisam monitorar qualidade, reproducibilidade e desempenho.\n- Notas para o autor:\n  - Evite jargões excessivos; use exemplos simples (ex.: LangChain como “caixa de ferramentas de construção” e LangSmith como “laboratório de observabilidade”).\n  - Ressalte a relação de dependência: LangSmith funciona para aplicações criadas com LangChain.\n\n3) Diferenças-chave (comparação direta)\n- Finalidade:\n  - LangChain: construir e orquestrar fluxos de LLMs (chains, prompts, memory, agentes).\n  - LangSmith: observar, testar, depurar e medir a execução dessas aplicações.\n- Função principal:\n  - LangChain: fornece estruturas de código, APIs, abstrações para lidar com entrada/saída, estado, fluxos de decisão.\n  - LangSmith: captura dados de runs (entradas, saídas, prompts, passos, métricas) e oferece análise/visualização.\n- Usuários típicos:\n  - LangChain: desenvolvedores de aplicações de IA, engenheiros de prompt, criadores de pipelines.\n  - LangSmith: engenheiros de QA/produção, analistas de performance, gerentes de qualidade.\n- Componentes/entrega:\n  - LangChain: biblioteca de código (Python, JavaScript/TypeScript), utilitários de prompt, memória, memória de contexto, etc.\n  - LangSmith: plataforma/web dashboards, APIs para gravar/run analytics, visualizações de prompts e fluxos.\n- Integração:\n  - LangSmith complementa LangChain; não substitui o framework de construção.\n- Notas para o autor:\n  - Use exemplos curtos para ilustrar cada ponto (ex.: “um chain simples vs. a gravação desse chain com LangSmith”).\n  - Aponte que LangSmith depende de LangChain para coletar dados de runs.\n\n4) Como funcionam juntos no fluxo de trabalho\n- Descrição do fluxo típico:\n  - 1) Desenvolver com LangChain: criar chains, prompts, memory, e agentes.\n  - 2) Rodar a aplicação localmente ou em produção.\n  - 3) Ativar LangSmith para registrar execuções (runs), prompts usados, entradas/saídas, métricas.\n  - 4) Analisar os dados em LangSmith para depuração, comparação entre versões de prompts/fluxos, e melhoria de desempenho.\n- Notas para o autor:\n  - Inclua um mini-exemplo de pipeline: “Coletar entrada do usuário → processar ...
# ---------------------------------------------------------------------------
# InvalidUpdateError                        Traceback (most recent call last)
# Cell In[41], line 2
#       1 thread = {"configurable": {"thread_id": "1"}}
# ----> 2 for s in graph.stream({
#       3     'task': "Qual é a diferença entre o langchain e langsmith",
#       4     "max_revisions": 2,
#       5     "revision_number": 1,
#
# File ~/Study/Alura/LangGraph_Orquestrando_agentes/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:2999, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2982 for _ in runner.tick(
#    2983     [t for t in loop.tasks.values() if not t.writes],
#    2984     timeout=self.step_timeout,
#    (...)   2987 ):
#    2988     # emit output
#    2989     yield from _output(
#    2990         stream_mode,
#    2991         print_mode,
#    (...)   2997         _state_mapper,
#    2998     )
# -> 2999 loop.after_tick()
#    3000 emit_graph_lifecycle_events(loop)
#    3001 # wait for checkpoint
#
# File ~/Study/Alura/LangGraph_Orquestrando_agentes/.venv/lib/python3.12/site-packages/langgraph/pregel/_loop.py:680, in PregelLoop.after_tick(self)
#     678 writes = [w for t in self.tasks.values() for w in t.writes]
#     679 # all tasks have finished
# --> 680 self.updated_channels = apply_writes(
#     681     self.checkpoint,
#     682     self.channels,
#     683     self.tasks.values(),
#     684     self.checkpointer_get_next_version,
#     685     self.trigger_to_nodes,
#     686 )
#     687 # produce values output
#     688 if not self.updated_channels.isdisjoint(
#     689     (self.output_keys,)
#     690     if isinstance(self.output_keys, str)
#     691     else self.output_keys
#     692 ):
#
# File ~/Study/Alura/LangGraph_Orquestrando_agentes/.venv/lib/python3.12/site-packages/langgraph/pregel/_algo.py:319, in apply_writes(checkpoint, channels, tasks, get_next_version, trigger_to_nodes)
#     317 for chan, vals in pending_writes_by_channel.items():
#     318     if chan in channels:
# --> 319         if channels[chan].update(vals) and next_version is not None:
#     320             checkpoint["channel_versions"][chan] = next_version
#     321             # unavailable channels can't trigger tasks, so don't add them
#
# File ~/Study/Alura/LangGraph_Orquestrando_agentes/.venv/lib/python3.12/site-packages/langgraph/channels/last_value.py:64, in LastValue.update(self, values)
#      59 if len(values) != 1:
#      60     msg = create_error_message(
#      61         message=f"At key '{self.key}': Can receive only one value per step. Use an Annotated key to handle multiple values.",
#      62         error_code=ErrorCode.INVALID_CONCURRENT_GRAPH_UPDATE,
#      63     )
# ---> 64     raise InvalidUpdateError(msg)
#      66 self.value = values[-1]
#      67 return True
#
# InvalidUpdateError: At key 'plan': Can receive only one value per step. Use an Annotated key to handle multiple values.
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langgraph/errors/INVALID_CONCURRENT_GRAPH_UPDATE
